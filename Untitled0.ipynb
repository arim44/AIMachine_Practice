# %%
list3 = list(range(1,10))
list4 = list(map(lambda x: x**2, list3))
print(list3)
list5 = [x**2 for x in list3]
print(5)
list6 = [x**2 for x in range(1,10)]
print(list6)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# 5
# [1, 4, 9, 16, 25, 36, 49, 64, 81]

# %% [markdown]
# # 여기는 컨텐츠를 넣는 공간 이미지 가능
